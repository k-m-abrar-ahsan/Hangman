# %%
cubeArr=[[[['r1','r2','r3'],
        ['r4','r5','r6'],
        ['r7','r8','r9']]],

        [[['b1','b2','b3'],
        ['b4','b5','b6'],
        ['b7','b8','b9']]],

        [[['O1','O2','O3'],
        ['O4','O5','O6'],
        ['O7','O8','O9']]],

        [[['g1','g2','g3'],
        ['g4','g5','g6'],
        ['g7','g8','g9']], [['y1','y2','y3'],
                            ['y4','y5','y6'],
                            ['y7','y8','y9']],
                                                [['w1','w2','w3'],
                                                ['w4','w5','w6'],
                                                ['w7','w8','w9']]]]

# %%
def reset():
    cubeArr=[[[['r1','r2','r3'],
        ['r4','r5','r6'],
        ['r7','r8','r9']]],

        [[['b1','b2','b3'],
        ['b4','b5','b6'],
        ['b7','b8','b9']]],

        [[['O1','O2','O3'],
        ['O4','O5','O6'],
        ['O7','O8','O9']]],

        [[['g1','g2','g3'],
        ['g4','g5','g6'],
        ['g7','g8','g9']], [['y1','y2','y3'],
                            ['y4','y5','y6'],
                            ['y7','y8','y9']],
                                                [['w1','w2','w3'],
                                                ['w4','w5','w6'],
                                                ['w7','w8','w9']]]]

# %%
def CubeShow():
    print(' ______________')
    print("| %s | %s | %s |" % (cubeArr[0][0][0][0],cubeArr[0][0][0][1],cubeArr[0][0][0][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[0][0][1][0],cubeArr[0][0][1][1],cubeArr[0][0][1][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[0][0][2][0],cubeArr[0][0][2][1],cubeArr[0][0][2][2]))
    print("|____|____|____|")


    print(' ______________')
    print("| %s | %s | %s |" % (cubeArr[1][0][0][0],cubeArr[1][0][0][1],cubeArr[1][0][0][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[1][0][1][0],cubeArr[1][0][1][1],cubeArr[1][0][1][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[1][0][2][0],cubeArr[1][0][2][1],cubeArr[1][0][2][2]))
    print("|____|____|____|")

    print(' ______________')
    print("| %s | %s | %s |" % (cubeArr[2][0][0][0],cubeArr[2][0][0][1],cubeArr[2][0][0][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[2][0][1][0],cubeArr[2][0][1][1],cubeArr[2][0][1][2]))
    print("|____|____|____|")
    print("| %s | %s | %s |" % (cubeArr[2][0][2][0],cubeArr[2][0][2][1],cubeArr[2][0][2][2]))
    print("|____|____|____|")
    #print('______________')

    print(' ______________   ______________   ______________')
    print("| %s | %s | %s | | %s | %s | %s | | %s | %s | %s |" % (cubeArr[3][0][0][0],cubeArr[3][0][0][1],cubeArr[3][0][0][2], cubeArr[3][1][0][0] ,cubeArr[3][1][0][1],cubeArr[3][1][0][2], cubeArr[3][2][0][0],cubeArr[3][2][0][1],cubeArr[3][2][0][2]))
    print("|____|____|____| |____|____|____| |____|____|____|")
    print("| %s | %s | %s | | %s | %s | %s | | %s | %s | %s |" % (cubeArr[3][0][1][0],cubeArr[3][0][1][1],cubeArr[3][0][1][2], cubeArr[3][1][1][0],cubeArr[3][1][1][1],cubeArr[3][1][1][2], cubeArr[3][2][1][0],cubeArr[3][2][1][1],cubeArr[3][2][1][2]))
    print("|____|____|____| |____|____|____| |____|____|____|")
    print("| %s | %s | %s | | %s | %s | %s | | %s | %s | %s |" % (cubeArr[3][0][2][0],cubeArr[3][0][2][1],cubeArr[3][0][2][2], cubeArr[3][1][2][0],cubeArr[3][1][2][1],cubeArr[3][1][2][2], cubeArr[3][2][2][0],cubeArr[3][2][2][1],cubeArr[3][2][2][2]))
    print("|____|____|____| |____|____|____| |____|____|____|")

CubeShow()
# Out:
#  ______________
# | r1 | r2 | r3 |
# |____|____|____|
# | r4 | r5 | r6 |
# |____|____|____|
# | r7 | r8 | r9 |
# |____|____|____|
#  ______________
# | b1 | b2 | b3 |
# |____|____|____|
# | b4 | b5 | b6 |
# |____|____|____|
# | b7 | b8 | b9 |
# |____|____|____|
#  ______________
# | O1 | O2 | O3 |
# |____|____|____|
# | O4 | O5 | O6 |
# |____|____|____|
# | O7 | O8 | O9 |
# |____|____|____|
#  ______________   ______________   ______________
# | g1 | g2 | g3 | | y1 | y2 | y3 | | w1 | w2 | w3 |
# |____|____|____| |____|____|____| |____|____|____|
# | g4 | g5 | g6 | | y4 | y5 | y6 | | w4 | w5 | w6 |
# |____|____|____| |____|____|____| |____|____|____|
# | g7 | g8 | g9 | | y7 | y8 | y9 | | w7 | w8 | w9 |
# |____|____|____| |____|____|____| |____|____|____|

# %%
def V1D():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[3][0][x][0])
    for i in range(3,-1,-1):
        for j in range(0,3):
            cubeArr[i][0][j][0]=cubeArr[i-1][0][j][0]
    for y in range(0,3):
        cubeArr[0][0][y][0]=temp[y]

    d,e,f=[],[],[]

    for j in range(0,3):
        d.append(cubeArr[3][1][j][0])#[::-1]
        e.append(cubeArr[3][1][j][1])
        f.append(cubeArr[3][1][j][2])
    temp_list=[d[::-1],e[::-1],f[::-1]]

    for i in range(0,3):
        cubeArr[3][1][i]=temp_list[i]

# %%
def V2D():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[3][0][x][1])
    for i in range(3,-1,-1):
        for j in range(0,3):
            cubeArr[i][0][j][1]=cubeArr[i-1][0][j][1]
    for y in range(0,3):
        cubeArr[0][0][y][1]=temp[y]

# %%
def V3D():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[3][0][x][2])
    for i in range(3,-1,-1):
        for j in range(0,3):
            cubeArr[i][0][j][2]=cubeArr[i-1][0][j][2]
    for y in range(0,3):
        cubeArr[0][0][y][2]=temp[y]

    d,e,f=[],[],[]

    for j in range(0,3):
        d.append(cubeArr[3][2][j][0])#[::-1]
        e.append(cubeArr[3][2][j][1])
        f.append(cubeArr[3][2][j][2])
    temp_list=[d[::-1],e[::-1],f[::-1]]

    for i in range(0,3):
        cubeArr[3][2][i]=temp_list[i]

# %%
def V1U():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[0][0][x][0])
    for i in range(0,3):
        for j in range(0,3):
            cubeArr[i][0][j][0]=cubeArr[i+1][0][j][0]
    for y in range(0,3):
        cubeArr[3][0][y][0]=temp[y]

    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[3][1][j][0])#[::-1]
        e.append(cubeArr[3][1][j][1])
        d.append(cubeArr[3][1][j][2])
    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[3][1][i]=temp_list[i]

# %%
def V2U():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[0][0][x][1])
    for i in range(0,3):
        for j in range(0,3):
            cubeArr[i][0][j][1]=cubeArr[i+1][0][j][1]
    for y in range(0,3):
        cubeArr[3][0][y][1]=temp[y]

# %%
def V3U():
    temp=[]
    for x in range(0,3):
        temp.append(cubeArr[0][0][x][2])
    for i in range(0,3):
        for j in range(0,3):
            cubeArr[i][0][j][2]=cubeArr[i+1][0][j][2]
    for y in range(0,3):
        cubeArr[3][0][y][2]=temp[y]

    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[3][2][j][0])#[::-1]
        e.append(cubeArr[3][2][j][1])
        d.append(cubeArr[3][2][j][2])
    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[3][2][i]=temp_list[i]

# %%
def H1R():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][0][i])

    #cubeArr[0][0][0][0]=cubeArr[3][1][0][0]
    #cubeArr[0][0][0][1]=cubeArr[3][1][0][1]
    #cubeArr[0][0][0][2]=cubeArr[3][1][0][2]
    #cubeArr[3][1][0][0],cubeArr[3][1][0][1],cubeArr[3][1][0][2]=cubeArr[3][0][0][0],cubeArr[3][0][0][1],cubeArr[3][0][0][2]
    #cubeArr[3][0][0][0],cubeArr[3][0][0][1],cubeArr[3][0][0][2]=cubeArr[3][2][0][0],cubeArr[3][2][0][1],cubeArr[3][2][0][2]

    for i in range(0,3):
        cubeArr[3][2][0][i]=cubeArr[1][0][0][i]
    for i in range(0,3):
        cubeArr[1][0][0][i]=cubeArr[3][1][0][i]
    for i in range(0,3):
        cubeArr[3][1][0][i]=cubeArr[3][0][0][i]

    for i in range(0,3):
        cubeArr[3][0][0][i]=temp[i]

    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[2][0][j][0])#[::-1]
        e.append(cubeArr[2][0][j][1])
        d.append(cubeArr[2][0][j][2])
    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[2][0][i]=temp_list[i]

# %%
def H2R():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][1][i])

    for i in range(0,3):
        cubeArr[3][2][1][i]=cubeArr[1][0][1][i]
    for i in range(0,3):
        cubeArr[1][0][1][i]=cubeArr[3][1][1][i]
    for i in range(0,3):
        cubeArr[3][1][1][i]=cubeArr[3][0][1][i]

    for i in range(0,3):
        cubeArr[3][0][1][i]=temp[i]

# %%
def H3R():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][2][i])


    for i in range(0,3):
        cubeArr[3][2][2][i]=cubeArr[1][0][2][i]
    for i in range(0,3):
        cubeArr[1][0][2][i]=cubeArr[3][1][2][i]
    for i in range(0,3):
        cubeArr[3][1][2][i]=cubeArr[3][0][2][i]


    for i in range(0,3):
        cubeArr[3][0][2][i]=temp[i]


    d,e,f=[],[],[]
    for j in range(0,3):
        f.append(cubeArr[0][0][j][0])#[::-1]
        e.append(cubeArr[0][0][j][1])
        d.append(cubeArr[0][0][j][2])
    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[0][0][i]=temp_list[i]

# %%
def H1L():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][0][0][i])

    for i in range(0,3):
        cubeArr[3][0][0][i]=cubeArr[3][1][0][i]
    for i in range(0,3):
        cubeArr[3][1][0][i]=cubeArr[1][0][0][i]
    for i in range(0,3):
        cubeArr[1][0][0][i]=cubeArr[3][2][0][i]

    for i in range(0,3):
        cubeArr[3][2][0][i]=temp[i]

    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[2][0][j][0])#[::-1]
        e.append(cubeArr[2][0][j][1])
        d.append(cubeArr[2][0][j][2])
    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[2][0][i]=temp_list[i]

# %%
def H2L():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][0][1][i])

    for i in range(0,3):
        cubeArr[3][0][1][i]=cubeArr[3][1][1][i]
    for i in range(0,3):
        cubeArr[3][1][1][i]=cubeArr[1][0][1][i]
    for i in range(0,3):
        cubeArr[1][0][1][i]=cubeArr[3][2][1][i]

    for i in range(0,3):
        cubeArr[3][2][1][i]=temp[i]

# %%
def H3L():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][0][2][i])


    for i in range(0,3):
        cubeArr[3][0][2][i]=cubeArr[3][1][2][i]
    for i in range(0,3):
        cubeArr[3][1][2][i]=cubeArr[1][0][2][i]
    for i in range(0,3):
        cubeArr[1][0][2][i]=cubeArr[3][2][2][i]

    for i in range(0,3):
        cubeArr[3][2][2][i]=temp[i]

    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[0][0][j][0])#[::-1]
        e.append(cubeArr[0][0][j][1])
        d.append(cubeArr[0][0][j][2])
    temp_list=[d[::-1],e[::-1],f[::-1]]

    for i in range(0,3):
        cubeArr[0][0][i]=temp_list[i]

# %%
def FF1AC():
    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[3][0][j][0])#[::-1]
        e.append(cubeArr[3][0][j][1])
        d.append(cubeArr[3][0][j][2])

    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[3][0][i]=temp_list[i]

    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][1][i][0])

    for i in range(0,3):
        cubeArr[3][1][i][0]=cubeArr[0][0][0][i]
    for i in range(0,3):
        cubeArr[0][0][0][i]=cubeArr[3][2][i][2]
    for i in range(0,3):
        cubeArr[3][2][i][2]=cubeArr[2][0][2][i]

    for i in range(0,3):
        cubeArr[2][0][2][i]=temp[i]

# %%
def FF2AC():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][1][i][0])

    for i in range(0,3):
        cubeArr[3][1][i][0]=cubeArr[0][0][0][i]
    for i in range(0,3):
        cubeArr[0][0][0][i]=cubeArr[3][2][i][2]
    for i in range(0,3):
        cubeArr[3][2][i][2]=cubeArr[2][0][2][i]

    for i in range(0,3):
        cubeArr[2][0][2][i]=temp[i]

# %%
def FF3AC():
    d,e,f=[],[],[]
    for j in range(0,3):
        f.append(cubeArr[1][0][j][0])#[::-1]
        e.append(cubeArr[1][0][j][1])
        d.append(cubeArr[1][0][j][2])

    temp_list=[d,e,f]

    for i in range(0,3):
        cubeArr[1][0][i]=temp_list[i]

    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][1][i][2])

    for i in range(0,3):
        cubeArr[3][1][i][0]=cubeArr[2][0][0][i]
    for i in range(0,3):
        cubeArr[2][0][0][i]=cubeArr[3][2][i][0]
    for i in range(0,3):
        cubeArr[3][2][i][0]=cubeArr[0][0][2][i]

    for i in range(0,3):
        cubeArr[0][0][2][i]=temp[i]

# %%
def FF1C():
    d,e,f=[],[],[]

    for j in range(0,3):
        f.append(cubeArr[3][0][j][0])#[::-1]
        e.append(cubeArr[3][0][j][1])
        d.append(cubeArr[3][0][j][2])

    temp_list=[d[::-1],e[::-1],f[::-1]]

    for i in range(0,3):
        cubeArr[3][0][i]=temp_list[i]

    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][i][2])

    for i in range(0,3):
        cubeArr[3][2][i][2]=cubeArr[0][0][0][i]
    for i in range(0,3):
        cubeArr[0][0][0][i]=cubeArr[3][1][i][0]
    for i in range(0,3):
        cubeArr[3][1][i][0]=cubeArr[2][0][2][i]

    for i in range(0,3):
        cubeArr[2][0][2][i]=temp[i]

# %%
def FF2C():
    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][i][1])

    for i in range(0,3):
        cubeArr[3][2][i][1]=cubeArr[0][0][1][i]
    for i in range(0,3):
        cubeArr[0][0][1][i]=cubeArr[3][1][i][1]
    for i in range(0,3):
        cubeArr[3][1][i][1]=cubeArr[2][0][1][i]

    for i in range(0,3):
        cubeArr[2][0][1][i]=temp[i]

# %%
def FF3C():
    d,e,f=[],[],[]
    for j in range(0,3):
        f.append(cubeArr[1][0][j][0])#[::-1]
        e.append(cubeArr[1][0][j][1])
        d.append(cubeArr[1][0][j][2])

    temp_list=[d[::-1],e[::-1],f[::-1]]

    for i in range(0,3):
        cubeArr[1][0][i]=temp_list[i]

    temp=[]
    for i in range(0,3):
            temp.append(cubeArr[3][2][i][2])

    for i in range(0,3):
        cubeArr[3][2][i][2]=cubeArr[0][0][0][i]
    for i in range(0,3):
        cubeArr[0][0][0][i]=cubeArr[3][1][i][0]
    for i in range(0,3):
        cubeArr[3][1][i][0]=cubeArr[2][0][2][i]

    for i in range(0,3):
        cubeArr[2][0][2][i]=temp[i]

# %% [markdown]
# ##This is a rubik's cube simulator. Nothing more.
#
# To end it the input has to be anything but the moves.
#
# To reset the input has to be 'Reset'.
#
# The moves are as follows:
# ### H1R,H2R,H3R,H1L,H2L,H3L
# ### V1U,V2U,V3U,V1D,V2D,V3D
# ### FF1AC,FF2AC,FF3AC,FF1C,FF2C,FF3C

# %%
while True:
    inp=input().lower()
    if inp =='h1r':
        H1R()
        #CubeShow()
    elif inp =='h2r':
        H2R()
        #CubeShow()
    elif inp =='h3r':
        H3R()
        #CubeShow()
    elif inp =='h1l':
        H1L()
        #CubeShow()
    elif inp=='h2l':
        H2L()
        #CubeShow()
    elif inp =='h3l':
        H3L()
        #CubeShow()
    elif inp =='v1u':
        V1U()
        #CubeShow()
    elif inp =='v2u':
        V2U()
        #CubeShow()
    elif inp =='v3u':
        V3U()
        #CubeShow()
    elif inp =='v1d':
        V1D()
        #CubeShow()
    elif inp =='v2d':
        V2D()
        #CubeShow()
    elif inp =='v3d':
        V3D()
        #CubeShow()
    elif inp =='ff1ac':
        FF1AC()
        #CubeShow()
    elif inp =='ff2ac':
        FF2AC()
        #CubeShow()
    elif inp =='ff3ac':
        FF3AC()
        #CubeShow()
    elif inp =='ff1c':
        FF1C()
        #CubeShow()
    elif inp =='ff2c':
        FF2C()
        #CubeShow()
    elif inp =='ff3c':
        FF3C()
       # CubeShow()
    elif inp =='reset':
        reset()
        #CubeShow()
    elif inp=="show":
        CubeShow()
    else:
        break
# Out:
# v1d
#  ______________
# | g1 | r2 | r3 |
# |____|____|____|
# | g4 | r5 | r6 |
# |____|____|____|
# | g7 | r8 | r9 |
# |____|____|____|
#  ______________
# | r1 | b2 | b3 |
# |____|____|____|
# | r4 | b5 | b6 |
# |____|____|____|
# | r7 | b8 | b9 |
# |____|____|____|
#  ______________
# | b1 | O2 | O3 |
# |____|____|____|
# | b4 | O5 | O6 |
# |____|____|____|
# | b7 | O8 | O9 |
# |____|____|____|
#  ______________   ______________   ______________
# | O1 | g2 | g3 | | y7 | y4 | y1 | | w1 | w2 | w3 |
# |____|____|____| |____|____|____| |____|____|____|
# | O4 | g5 | g6 | | y8 | y5 | y2 | | w4 | w5 | w6 |
# |____|____|____| |____|____|____| |____|____|____|
# | O7 | g8 | g9 | | y9 | y6 | y3 | | w7 | w8 | w9 |
# |____|____|____| |____|____|____| |____|____|____|
# v1u
#  ______________
# | r1 | r2 | r3 |
# |____|____|____|
# | r4 | r5 | r6 |
# |____|____|____|
# | r7 | r8 | r9 |
# |____|____|____|
#  ______________
# | b1 | b2 | b3 |
# |____|____|____|
# | b4 | b5 | b6 |
# ...
